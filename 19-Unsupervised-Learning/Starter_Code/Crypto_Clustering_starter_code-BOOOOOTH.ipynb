# %%
# Import the required modules
import pandas as pd
pd.set_option('display.max_columns', None)
import numpy as np

# visualization
import matplotlib.pyplot as plt
import hvplot.pandas

# Machine Learning
from sklearn.cluster import KMeans, AgglomerativeClustering, Birch
from sklearn.metrics import silhouette_score, calinski_harabasz_score
from sklearn.manifold import TSNE

# Preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# suppress warnings
import warnings
warnings.filterwarnings('ignore')
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(> .cell-output-ipywidget-background
#     > .lm-Widget
#     > *[data-root-id]),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
# Load the data into a Pandas DataFrame
df = pd.read_csv("Resources/crypto_market_data.csv")

# Display sample data
df.head(10)
# Out:
#            coin_id  price_change_percentage_24h  price_change_percentage_7d  \
# 0          bitcoin                      1.08388                     7.60278
# 1         ethereum                      0.22392                    10.38134
# 2           tether                     -0.21173                     0.04935
# 3           ripple                     -0.37819                    -0.60926
# 4     bitcoin-cash                      2.90585                    17.09717
# 5      binancecoin                      2.10423                    12.85511
# 6        chainlink                     -0.23935                    20.69459
# 7          cardano                      0.00322                    13.99302
# 8         litecoin                     -0.06341                     6.60221
# 9  bitcoin-cash-sv                      0.92530                     3.29641
#
#    price_change_percentage_14d  price_change_percentage_30d  \
# 0                      6.57509                      7.67258
# 1                      4.80849                      0.13169
# 2                      0.00640                     -0.04237
# 3                      2.24984                      0.23455
# 4                     14.75334                     15.74903
# 5                      6.80688                      0.05865
# 6                      9.30098                    -11.21747
# 7                      5.55476                     10.10553
# 8                      7.28931                      1.21662
# 9                     -1.86656                      2.88926
#
#    price_change_percentage_60d  price_change_percentage_200d  \
# 0                     -3.25185                      83.51840
# 1                    -12.88890                     186.77418
# 2                      0.28037                      -0.00542
# 3                    -17.55245                      39.53888
# 4                    -13.71793                      21.66042
# 5                     36.33486                     155.61937
# 6                    -43.69522                     403.22917
# 7                    -22.84776                     264.51418
# 8                    -17.23960                      27.49919
# 9                    -24.87434                       7.42562
#
#    price_change_percentage_1y
# 0                    37.51761
# 1                   101.96023
# 2                     0.01954
# 3                   -16.60193
# 4                    14.49384
# 5                    69.69195
# 6                   325.13186
# 7                   156.09756
# 8                   -12.66408
# 9                    93.73082

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41 entries, 0 to 40
# Data columns (total 8 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   coin_id                       41 non-null     object
#  1   price_change_percentage_24h   41 non-null     float64
#  2   price_change_percentage_7d    41 non-null     float64
#  3   price_change_percentage_14d   41 non-null     float64
#  4   price_change_percentage_30d   41 non-null     float64
#  5   price_change_percentage_60d   41 non-null     float64
#  6   price_change_percentage_200d  41 non-null     float64
#  7   price_change_percentage_1y    41 non-null     float64
# dtypes: float64(7), object(1)
# memory usage: 2.7+ KB

# %%
# No NULLs and ALL are numeric :D

# %%
# Generate summary statistics
df.describe()
# Out:
#        price_change_percentage_24h  price_change_percentage_7d  \
# count                    41.000000                   41.000000
# mean                     -0.269686                    4.497147
# std                       2.694793                    6.375218
# min                     -13.527860                   -6.094560
# 25%                      -0.608970                    0.047260
# 50%                      -0.063410                    3.296410
# 75%                       0.612090                    7.602780
# max                       4.840330                   20.694590
#
#        price_change_percentage_14d  price_change_percentage_30d  \
# count                    41.000000                    41.000000
# mean                      0.185787                     1.545693
# std                       8.376939                    26.344218
# min                     -18.158900                   -34.705480
# 25%                      -5.026620                   -10.438470
# 50%                       0.109740                    -0.042370
# 75%                       5.510740                     4.578130
# max                      24.239190                   140.795700
#
#        price_change_percentage_60d  price_change_percentage_200d  \
# count                    41.000000                     41.000000
# mean                     -0.094119                    236.537432
# std                      47.365803                    435.225304
# min                     -44.822480                     -0.392100
# 25%                     -25.907990                     21.660420
# 50%                      -7.544550                     83.905200
# 75%                       0.657260                    216.177610
# max                     223.064370                   2227.927820
#
#        price_change_percentage_1y
# count                   41.000000
# mean                   347.667956
# std                   1247.842884
# min                    -17.567530
# 25%                      0.406170
# 50%                     69.691950
# 75%                    168.372510
# max                   7852.089700

# %%
# YES we need a scaler, too much variability in the maxes for each column range

# %%
# Plot your data to see what's in your DataFrame
df.hvplot.line(
    width=800,
    height=400,
    rot=90
)
# Out:
# :NdOverlay   [Variable]
#    :Curve   [index]   (value)

# %%
# are we independent? or suffer from multi-collinearity?
df.corr()
# Out:
#                               price_change_percentage_24h  \
# price_change_percentage_24h                      1.000000
# price_change_percentage_7d                       0.169659
# price_change_percentage_14d                      0.279682
# price_change_percentage_30d                      0.292563
# price_change_percentage_60d                      0.136974
# price_change_percentage_200d                    -0.541190
# price_change_percentage_1y                      -0.750630
#
#                               price_change_percentage_7d  \
# price_change_percentage_24h                     0.169659
# price_change_percentage_7d                      1.000000
# price_change_percentage_14d                     0.538294
# price_change_percentage_30d                     0.056899
# price_change_percentage_60d                    -0.145099
# price_change_percentage_200d                   -0.052533
# price_change_percentage_1y                     -0.038424
#
#                               price_change_percentage_14d  \
# price_change_percentage_24h                      0.279682
# price_change_percentage_7d                       0.538294
# price_change_percentage_14d                      1.000000
# price_change_percentage_30d                      0.658040
# price_change_percentage_60d                      0.376108
# price_change_percentage_200d                    -0.039086
# price_change_percentage_1y                      -0.116632
#
#                               price_change_percentage_30d  \
# price_change_percentage_24h                      0.292563
# price_change_percentage_7d                       0.056899
# price_change_percentage_14d                      0.658040
# price_change_percentage_30d                      1.000000
# price_change_percentage_60d                      0.745248
# price_change_percentage_200d                     0.324777
# price_change_percentage_1y                       0.016078
#
#                               price_change_percentage_60d  \
# price_change_percentage_24h                      0.136974
# price_change_percentage_7d                      -0.145099
# price_change_percentage_14d                      0.376108
# price_change_percentage_30d                      0.745248
# price_change_percentage_60d                      1.000000
# price_change_percentage_200d                     0.499102
# price_change_percentage_1y                       0.211242
#
#                               price_change_percentage_200d  \
# price_change_percentage_24h                      -0.541190
# price_change_percentage_7d                       -0.052533
# price_change_percentage_14d                      -0.039086
# price_change_percentage_30d                       0.324777
# price_change_percentage_60d                       0.499102
# price_change_percentage_200d                      1.000000
# price_change_percentage_1y                        0.879873
#
#                               price_change_percentage_1y
# price_change_percentage_24h                    -0.750630
# price_change_percentage_7d                     -0.038424
# price_change_percentage_14d                    -0.116632
# price_change_percentage_30d                     0.016078
# price_change_percentage_60d                     0.211242
# price_change_percentage_200d                    0.879873
# price_change_percentage_1y                      1.000000

# %%
# I think we need a scaler to NORMALIZE the Ranges
# SECOND I think we should do a PCA to limit the collinearity

# THEN - we'll do a TSNE, KMeans....

# %% [markdown]
# ---

# %% [markdown]
# ### Prepare the Data

# %%
df.columns
# Out:
# Index(['coin_id', 'price_change_percentage_24h', 'price_change_percentage_7d',
#        'price_change_percentage_14d', 'price_change_percentage_30d',
#        'price_change_percentage_60d', 'price_change_percentage_200d',
#        'price_change_percentage_1y'],
#       dtype='object')

# %%
# Use the `StandardScaler()` module from scikit-learn to normalize the data from the CSV file
num_features = [ 'price_change_percentage_24h', 'price_change_percentage_7d',
       'price_change_percentage_14d', 'price_change_percentage_30d',
       'price_change_percentage_60d', 'price_change_percentage_200d',
       'price_change_percentage_1y']

# %%
# subset
df_sub = df.loc[:, num_features]

# initialize
scaler = StandardScaler()

# fit
scaler.fit(df_sub)

# predict/transform
scaled_data = scaler.transform(df_sub)
df_scaled = pd.DataFrame(scaled_data, columns=num_features)

# bring back coin_id
df_scaled["coin_id"] = df.coin_id

df_scaled.head()
# Out:
#    price_change_percentage_24h  price_change_percentage_7d  \
# 0                     0.508529                    0.493193
# 1                     0.185446                    0.934445
# 2                     0.021774                   -0.706337
# 3                    -0.040764                   -0.810928
# 4                     1.193036                    2.000959
#
#    price_change_percentage_14d  price_change_percentage_30d  \
# 0                     0.772200                     0.235460
# 1                     0.558692                    -0.054341
# 2                    -0.021680                    -0.061030
# 3                     0.249458                    -0.050388
# 4                     1.760610                     0.545842
#
#    price_change_percentage_60d  price_change_percentage_200d  \
# 0                    -0.067495                     -0.355953
# 1                    -0.273483                     -0.115759
# 2                     0.008005                     -0.550247
# 3                    -0.373164                     -0.458259
# 4                    -0.291203                     -0.499848
#
#    price_change_percentage_1y       coin_id
# 0                   -0.251637       bitcoin
# 1                   -0.199352      ethereum
# 2                   -0.282061        tether
# 3                   -0.295546        ripple
# 4                   -0.270317  bitcoin-cash

# %%
 df_scaled.describe()
# Out:
#        price_change_percentage_24h  price_change_percentage_7d  \
# count                    41.000000                4.100000e+01
# mean                      0.000000                1.895503e-16
# std                       1.012423                1.012423e+00
# min                      -4.981042               -1.682027e+00
# 25%                      -0.127467               -7.066688e-01
# 50%                       0.077497               -1.906843e-01
# 75%                       0.331280                4.931931e-01
# max                       1.919812                2.572251e+00
#
#        price_change_percentage_14d  price_change_percentage_30d  \
# count                 4.100000e+01                 4.100000e+01
# mean                  2.707861e-17                 2.978647e-17
# std                   1.012423e+00                 1.012423e+00
# min                  -2.217108e+00                -1.393153e+00
# 25%                  -6.299628e-01                -4.605580e-01
# 50%                  -9.190922e-03                -6.103015e-02
# 75%                   6.435649e-01                 1.165382e-01
# max                   2.907054e+00                 5.351455e+00
#
#        price_change_percentage_60d  price_change_percentage_200d  \
# count                 4.100000e+01                  4.100000e+01
# mean                 -5.415722e-18                 -1.326852e-16
# std                   1.012423e+00                  1.012423e+00
# min                  -9.560487e-01                 -5.511464e-01
# 25%                  -5.517599e-01                 -4.998478e-01
# 50%                  -1.592496e-01                 -3.550537e-01
# 75%                   1.606038e-02                 -4.736110e-02
# max                   4.769913e+00                  4.632380e+00
#
#        price_change_percentage_1y
# count                4.100000e+01
# mean                 4.197185e-17
# std                  1.012423e+00
# min                 -2.963296e-01
# 25%                 -2.817468e-01
# 50%                 -2.255326e-01
# 75%                 -1.454693e-01
# max                  6.088625e+00

# %% [markdown]
# ---

# %% [markdown]
# ### Find the Best Value for k Using the Original Data.

# %%
# Create a list with the number of k-values from 1 to 11

# Define your "X" - features to predict
X = df_scaled.loc[:, num_features]
X.head()
# Out:
#    price_change_percentage_24h  price_change_percentage_7d  \
# 0                     0.508529                    0.493193
# 1                     0.185446                    0.934445
# 2                     0.021774                   -0.706337
# 3                    -0.040764                   -0.810928
# 4                     1.193036                    2.000959
#
#    price_change_percentage_14d  price_change_percentage_30d  \
# 0                     0.772200                     0.235460
# 1                     0.558692                    -0.054341
# 2                    -0.021680                    -0.061030
# 3                     0.249458                    -0.050388
# 4                     1.760610                     0.545842
#
#    price_change_percentage_60d  price_change_percentage_200d  \
# 0                    -0.067495                     -0.355953
# 1                    -0.273483                     -0.115759
# 2                     0.008005                     -0.550247
# 3                    -0.373164                     -0.458259
# 4                    -0.291203                     -0.499848
#
#    price_change_percentage_1y
# 0                   -0.251637
# 1                   -0.199352
# 2                   -0.282061
# 3                   -0.295546
# 4                   -0.270317

# %%
# Can this even be clustered?
# TSNE doesn't really work because we don't have enough rows/data :(
tsne2 = TSNE()
df_tsne2 = pd.DataFrame(tsne2.fit_transform(X)) # fit SCALED data first

# Plot the clusters
plt.scatter(df_tsne2[0], df_tsne2[1])
plt.title("TSNE on SCALED Data")
plt.show()

# %%
 # Create a a list to store inertia values
inertia = []
silhouettes = []
cha_chas = []

# Create a a list to store the values of k
k = list(range(2, 11))

# Create a for-loop where each value of k is evaluated using the K-means algorithm
# Fit the model using the spread_df DataFrame
# Append the value of the computed inertia from the `inertia_` attribute of the KMeans model instance
for i in k:
    # initialize the model
    k_model = KMeans(n_clusters=i, random_state=1)
    
    # fit the model
    k_model.fit(X)
    
    # predict the model
    preds = k_model.predict(X)
    
    # evaluate the model (generate the metics)
    inertia.append(k_model.inertia_)
    score = silhouette_score(X, preds)
    silhouettes.append(score)
    
    cha_cha = calinski_harabasz_score(X, preds)
    cha_chas.append(cha_cha)
    
    print(f"Finished {i} out of {max(k)}")
# Out:
# Finished 2 out of 10
# Finished 3 out of 10
# Finished 4 out of 10
# Finished 5 out of 10
# Finished 6 out of 10
# Finished 7 out of 10
# Finished 8 out of 10
# Finished 9 out of 10
# Finished 10 out of 10

# %%
 # Define a DataFrame to hold the values for k and the corresponding inertia
elbow_data = {"k": k, "inertia": inertia, "silhouette_score": silhouettes, "cha_score": cha_chas}
df_elbow = pd.DataFrame(elbow_data)

df_elbow["acc"] = df_elbow.inertia.diff()

# Review the DataFrame
df_elbow.head(10)
# Out:
#     k     inertia  silhouette_score  cha_score        acc
# 0   2  195.820218          0.651576  18.159573        NaN
# 1   3  123.190482          0.702822  25.264783 -72.629736
# 2   4   79.022435          0.314482  32.459853 -44.168046
# 3   5   65.405923          0.251511  30.491836 -13.616512
# 4   6   52.933559          0.293221  30.953239 -12.472365
# 5   7   47.983124          0.237507  28.227194  -4.950435
# 6   8   37.288187          0.256063  31.570664 -10.694937
# 7   9   33.061685          0.205528  30.722973  -4.226502
# 8  10   28.779752          0.238327  30.904550  -4.281932

# %%
# Plot a line chart with all the inertia values computed with 
# the different values of k to visually identify the optimal value for k.

# Plot the DataFrame
plt.plot(df_elbow["k"], df_elbow["inertia"])
plt.title("Elbow Curve")
plt.xticks(df_elbow["k"])
plt.ylabel("inertia")
plt.xlabel("k")
plt.show()

# %% [markdown]
# #### Answer the following question:
#
# **Question:** What is the best value for `k`?
#
# **Answer:** 4? Maybe 3? 3 actually is bad if  you run it below

# %% [markdown]
# ---

# %% [markdown]
# ### Cluster Cryptocurrencies with K-means Using the Original Data

# %%
# Initialize the K-Means model using the best value for k

# %%
# Fit the K-Means model using the scaled data

# %%
# Predict the clusters to group the cryptocurrencies using the scaled data


# Print the resulting array of cluster values.

# %%
# Create a copy of the DataFrame

# %%
# Define the model with the higher value of k clusters
# Use a random_state of 1 to generate the model

# CHANGE THIS DEPENDING ON YOUR OPTIMAL k
model = KMeans(n_clusters=4, random_state=1)

# Fit the model
model.fit(X)

# Make predictions
preds = model.predict(X)

# Add a class column with the labels to the df DataFrame
df2 = df_scaled.copy()
df2['clusters'] = preds

df2.head()
# Out:
#    price_change_percentage_24h  price_change_percentage_7d  \
# 0                     0.508529                    0.493193
# 1                     0.185446                    0.934445
# 2                     0.021774                   -0.706337
# 3                    -0.040764                   -0.810928
# 4                     1.193036                    2.000959
#
#    price_change_percentage_14d  price_change_percentage_30d  \
# 0                     0.772200                     0.235460
# 1                     0.558692                    -0.054341
# 2                    -0.021680                    -0.061030
# 3                     0.249458                    -0.050388
# 4                     1.760610                     0.545842
#
#    price_change_percentage_60d  price_change_percentage_200d  \
# 0                    -0.067495                     -0.355953
# 1                    -0.273483                     -0.115759
# 2                     0.008005                     -0.550247
# 3                    -0.373164                     -0.458259
# 4                    -0.291203                     -0.499848
#
#    price_change_percentage_1y       coin_id  clusters
# 0                   -0.251637       bitcoin         3
# 1                   -0.199352      ethereum         3
# 2                   -0.282061        tether         1
# 3                   -0.295546        ripple         1
# 4                   -0.270317  bitcoin-cash         3

# %%
# Create a scatter plot using hvPlot by setting 
# `x="price_change_percentage_24h"` and `y="price_change_percentage_7d"`. 
# Color the graph points with the labels found using K-Means and 
# add the crypto name in the `hover_cols` parameter to identify 
# the cryptocurrency represented by each data point.
df2.hvplot.scatter(
    width=800,
    height=400,
    x="price_change_percentage_24h",
    y="price_change_percentage_7d",
    by="clusters",
    hover_cols="coin_id"
)
# Out:
# :NdOverlay   [clusters]
#    :Scatter   [price_change_percentage_24h]   (price_change_percentage_7d,coin_id)

# %%
df2.clusters.value_counts()
# Out:
# 1    26
# 3    13
# 0     1
# 2     1
# Name: clusters, dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# ### Optimize Clusters with Principal Component Analysis.

# %%
# PCA
# REASON WHY - because we have a TON of correlations - which is bad sometimes

# %%
# Instantiate the PCA instance and declare the number of PCA variables
num_pca = len(num_features)
pca = PCA(n_components=num_pca)

# Fit the PCA model on the transformed credit card DataFrame
data_pca = pca.fit_transform(df_scaled.loc[:, num_features])

# Create the PCA DataFrame
df_pca = pd.DataFrame(
    data_pca,
    columns=[f"PCA{x+1}" for x in range(num_pca)]
)

df_pca["coin_id"] = df_scaled.coin_id
df_pca.head()
# Out:
#        PCA1      PCA2      PCA3      PCA4      PCA5      PCA6      PCA7  \
# 0 -0.600667  0.842760  0.461595 -0.109151 -0.033786 -0.225703  0.006595
# 1 -0.458261  0.458466  0.952877  0.095100  0.014588  0.034158  0.109593
# 2 -0.433070 -0.168126 -0.641752 -0.470282  0.115300 -0.127710 -0.086857
# 3 -0.471835 -0.222660 -0.479053 -0.737473 -0.148641 -0.273472  0.134870
# 4 -1.157800  2.041209  1.859715  0.236479 -0.191787 -0.411513 -0.070411
#
#         coin_id
# 0       bitcoin
# 1      ethereum
# 2        tether
# 3        ripple
# 4  bitcoin-cash

# %%
# YAY we removed the multi-collinearity
df_pca.corr()
# Out:
#               PCA1          PCA2          PCA3          PCA4          PCA5  \
# PCA1  1.000000e+00  2.599562e-16  1.095974e-16  7.434809e-17 -1.343605e-17
# PCA2  2.599562e-16  1.000000e+00 -3.322026e-16 -1.326485e-16 -2.980973e-17
# PCA3  1.095974e-16 -3.322026e-16  1.000000e+00  2.315917e-16 -2.232150e-17
# PCA4  7.434809e-17 -1.326485e-16  2.315917e-16  1.000000e+00 -5.881178e-17
# PCA5 -1.343605e-17 -2.980973e-17 -2.232150e-17 -5.881178e-17  1.000000e+00
# PCA6 -2.088502e-16 -1.292298e-16 -2.892237e-16 -1.199061e-16 -3.649550e-17
# PCA7  1.230570e-17 -2.548176e-18  4.650926e-17  1.256828e-17  1.817052e-17
#
#               PCA6          PCA7
# PCA1 -2.088502e-16  1.230570e-17
# PCA2 -1.292298e-16 -2.548176e-18
# PCA3 -2.892237e-16  4.650926e-17
# PCA4 -1.199061e-16  1.256828e-17
# PCA5 -3.649550e-17  1.817052e-17
# PCA6  1.000000e+00 -1.374611e-16
# PCA7 -1.374611e-16  1.000000e+00

# %%
# Can we reduce the dimensions?

# Calculate the PCA explained variance ratio
exp_var = pca.explained_variance_ratio_

plt.plot(range(1, num_pca + 1), exp_var)
plt.title("Explained Variance Graph")
plt.xlabel("PCA #")
plt.ylabel("Explained Variance")
plt.xticks(range(1, num_pca + 1))
plt.show()

# %%
print("Explained Variance")
for i in range(len(exp_var)):
    val = exp_var[i]
    print(f"PCA{i+1}:", round(val, 3))

print()
print("CUMULATIVE Explained Variance")

exp_var_cum = np.cumsum(exp_var)
for i in range(len(exp_var_cum)):
    val = exp_var_cum[i]
    print(f"PCA{i+1}:", round(val, 3))
# Out:
# Explained Variance
# PCA1: 0.372
# PCA2: 0.347
# PCA3: 0.176
# PCA4: 0.057
# PCA5: 0.027
# PCA6: 0.016
# PCA7: 0.004
#
# CUMULATIVE Explained Variance
# PCA1: 0.372
# PCA2: 0.719
# PCA3: 0.895
# PCA4: 0.952
# PCA5: 0.979
# PCA6: 0.996
# PCA7: 1.0

# %%
# Use the PCA model with `fit_transform` to reduce to 
# three principal components.

# View the first five rows of the DataFrame. (BOOOTH like 4 better)
df3 = df_pca.loc[:, ["PCA1", "PCA2", "PCA3", "PCA4", "coin_id"]]
df3.head()
# Out:
#        PCA1      PCA2      PCA3      PCA4       coin_id
# 0 -0.600667  0.842760  0.461595 -0.109151       bitcoin
# 1 -0.458261  0.458466  0.952877  0.095100      ethereum
# 2 -0.433070 -0.168126 -0.641752 -0.470282        tether
# 3 -0.471835 -0.222660 -0.479053 -0.737473        ripple
# 4 -1.157800  2.041209  1.859715  0.236479  bitcoin-cash

# %%
# Retrieve the explained variance to determine how much information 
# can be attributed to each principal component.

# %% [markdown]
# #### Answer the following question:
#
# **Question:** What is the total explained variance of the three principal components?
#
# **Answer:**

# %%
# Create a new DataFrame with the PCA data.

# Creating a DataFrame with the PCA data

# Copy the crypto names from the original data


# Set the coinid column as index


# Display sample data

# %% [markdown]
# ---

# %% [markdown]
# ### Find the Best Value for k Using the PCA Data

# %%
# Create a list with the number of k-values from 1 to 11
# Define your "X" - features to predict
X = df3.loc[:, ["PCA1", "PCA2", "PCA3", "PCA4"]]
X.head()
# Out:
#        PCA1      PCA2      PCA3      PCA4
# 0 -0.600667  0.842760  0.461595 -0.109151
# 1 -0.458261  0.458466  0.952877  0.095100
# 2 -0.433070 -0.168126 -0.641752 -0.470282
# 3 -0.471835 -0.222660 -0.479053 -0.737473
# 4 -1.157800  2.041209  1.859715  0.236479

# %%
 # Create a a list to store inertia values
inertia = []
silhouettes = []
cha_chas = []

# Create a a list to store the values of k
k = list(range(2, 11))

# Create a for-loop where each value of k is evaluated using the K-means algorithm
# Fit the model using the spread_df DataFrame
# Append the value of the computed inertia from the `inertia_` attribute of the KMeans model instance
for i in k:
    # initialize the model
    k_model = KMeans(n_clusters=i, random_state=1)
    
    # fit the model
    k_model.fit(X)
    
    # predict the model
    preds = k_model.predict(X)
    
    # evaluate the model (generate the metics)
    inertia.append(k_model.inertia_)
    score = silhouette_score(X, preds)
    silhouettes.append(score)
    
    cha_cha = calinski_harabasz_score(X, preds)
    cha_chas.append(cha_cha)
    
    print(f"Finished {i} out of {max(k)}")
# Out:
# Finished 2 out of 10
# Finished 3 out of 10
# Finished 4 out of 10
# Finished 5 out of 10
# Finished 6 out of 10
# Finished 7 out of 10
# Finished 8 out of 10
# Finished 9 out of 10
# Finished 10 out of 10

# %%
 # Define a DataFrame to hold the values for k and the corresponding inertia
elbow_data = {"k": k, "inertia": inertia, "silhouette_score": silhouettes, "cha_score": cha_chas}
df_elbow = pd.DataFrame(elbow_data)

df_elbow["acc"] = df_elbow.inertia.diff()

# Review the DataFrame
df_elbow.head(10)
# Out:
#     k     inertia  silhouette_score  cha_score        acc
# 0   2  182.193841          0.667967  19.491139        NaN
# 1   3  110.149077          0.719133  28.133740 -72.044764
# 2   4   66.035401          0.355127  38.701044 -44.113676
# 3   5   52.618525          0.297483  37.737234 -13.416876
# 4   6   41.630404          0.332386  38.945881 -10.988121
# 5   7   33.041782          0.336464  41.195608  -8.588622
# 6   8   26.108712          0.272847  44.624631  -6.933070
# 7   9   22.504424          0.240890  44.568116  -3.604288
# 8  10   19.205601          0.263989  45.561689  -3.298823

# %%
# Plot a line chart with all the inertia values computed with 
# the different values of k to visually identify the optimal value for k.

# Plot the DataFrame
plt.plot(df_elbow["k"], df_elbow["inertia"])
plt.title("Elbow Curve")
plt.xticks(df_elbow["k"])
plt.ylabel("inertia")
plt.xlabel("k")
plt.show()

# %% [markdown]
# #### Answer the following questions:
#
# * **Question:** What is the best value for `k` when using the PCA data?
#
#   * **Answer:** 4
#
#
# * **Question:** Does it differ from the best k value found using the original data?
#
#   * **Answer:** No, it's actually a bit clearer

# %% [markdown]
# ### Cluster Cryptocurrencies with K-means Using the PCA Data

# %%
# Initialize the K-Means model using the best value for k

# %%
# Fit the K-Means model using the PCA data

# %%
# Predict the clusters to group the cryptocurrencies using the PCA data

# Print the resulting array of cluster values.

# %%
# Define the model with the higher value of k clusters
# Use a random_state of 1 to generate the model

# CHANGE THIS DEPENDING ON YOUR OPTIMAL k
model = KMeans(n_clusters=4, random_state=1)

# Fit the model
model.fit(X)

# Make predictions
preds = model.predict(X)

# Add a class column with the labels to the df DataFrame
df4 = df3.copy()
df4['clusters'] = preds

df4.head()
# Out:
#        PCA1      PCA2      PCA3      PCA4       coin_id  clusters
# 0 -0.600667  0.842760  0.461595 -0.109151       bitcoin         1
# 1 -0.458261  0.458466  0.952877  0.095100      ethereum         1
# 2 -0.433070 -0.168126 -0.641752 -0.470282        tether         0
# 3 -0.471835 -0.222660 -0.479053 -0.737473        ripple         0
# 4 -1.157800  2.041209  1.859715  0.236479  bitcoin-cash         1

# %%
# Create a scatter plot using hvPlot by setting 
# `x="PC1"` and `y="PC2"`. 
# Color the graph points with the labels found using K-Means and 
# add the crypto name in the `hover_cols` parameter to identify 
# the cryptocurrency represented by each data point.
df4.hvplot.scatter(
    width=800,
    height=400,
    x="PCA1",
    y="PCA2",
    by="clusters",
    hover_cols="coin_id"
)
# Out:
# :NdOverlay   [clusters]
#    :Scatter   [PCA1]   (PCA2,coin_id)

# %% [markdown]
# ### Visualize and Compare the Results
#
# In this section, you will visually analyze the cluster analysis results by contrasting the outcome with and without using the optimization techniques.

# %%
# Composite plot to contrast the Elbow curves

# %%
# Composite plot to contrast the clusters
# YOUR CODE HERE!

# %% [markdown]
# #### Answer the following question:
#
#   * **Question:** After visually analyzing the cluster analysis results, what is the impact of using fewer features to cluster the data using K-Means?
#
#   * **Answer:**
